# %%
# Lab2 . 
# Read in the file pichu.txt and pikachu.txt,test_points.txt in Python. 
path1 = "../Files/pichu.txt" 
path2 = "../Files/pikachu.txt"
path3 = "../Files/test_points.txt"

with open(path1, "r") as f1, open(path2, "r") as f2,open(path3, "r") as f3:
     text1=f1.read()
     text2=f2.read()
     text3=f3.read()
     print((text1))
     print(text2)   
     print(text3)
# Out:
# (width (cm), height (cm))
# (20.11541438766307, 28.701809671168824)
# (15.200086041781336, 27.095070307714877)
# (17.200234546952956, 27.669778220491132)
# (16.785685905190583, 34.36654587712494)
# (20.8917697133121, 31.480353852465935)
# (20.41359589938329, 31.091310056669883)
# (22.137436541638763, 26.71138648198097)
# (15.695510661035328, 32.291267979503495)
# (18.375374557482164, 26.634024937619284)
# (15.238377755504562, 28.794554417576478)
# (16.749103798428827, 34.895233506365955)
# (19.042842304826898, 31.399997598540928)
# (15.212287757470909, 30.569497437746463)
# (16.59070120549319, 31.846142509898748)
# (20.199075502236184, 33.4285192018981)
# (19.35953184482573, 32.75999911546245)
# (16.763524976325574, 27.290480719641042)
# (19.71412547100727, 25.321002439040377)
# (21.475443653422612, 28.154530480590818)
# (15.051990077424488, 27.67740875975703)
# (21.446554014662464, 27.109828435863264)
# (20.585115159905815, 34.429097143350546)
# ...

# %%
# Uppgift 1
# Gör dessa uppgifter när du klassificerat testdatan korrekt.正确分类测试数据后执行此信息。
# Låt användaren mata in en testpunkt och avgör om den dess klass. 让用户输入一个测试点并决定它是否是它的类。

# Ta med felhanteringen som tar hand om negativa tal och icke-numeriska inputs. Se till att ha användarvänliga felmeddelanden.
# 包括处理负数和非数字输入的错误处理。 确保您有用户友好的错误消息。

# %%
#Uppgift2. 
# Den approachen vi använt med närmaste punkten kan klassificera fel när punkterna för respektive klass går in i varandra.  
 # 我们使用最近点的方法可以在每个类的点相互进入时对错误进行分类。
 # Nu ska du istället välja de fem närmaste punkterna till din testpunkt. Den klass testpunkten tillhör avgörs av majoritetsklassen av de närmaste punkterna. 
# 现在你应该选择离你最近的五个点测试点。 测试点所属的类由最近点的多数类决定。
