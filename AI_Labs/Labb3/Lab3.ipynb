# %%
#from math import pi 

# save
class Geometry(): #parent class
    def area(self):
        pass
    def perimeter(self):
        pass
    def volum(self):
        pass
    
    
class Circle(Geometry):#child class
    def __init__(self,x,y ,radius):
       self.x=x
       self.y=y
       self.radius=radius

    def area(self):
        "Caculate the area of the circle"
        return 3.1415* self.radius**2  #pi=3.1415 

    def perimeter(self):
        "Caculate the perimeter of the circle"
        return 2*3.1415*self.radius 

    def move(self,deltaX,deltaY):
        self.x +=deltaX
        self.y +=deltaY   

    def is_inside(self,givenX,givenY,x,y,radius): # at given point
        self.x=x
        self.y=y
        self.radius=radius
        
        if((x-givenX)*2+ (y-givenY)*2<=radius*2):
            return True;
        else:
             return False;   

        
    #def __str__(self): 
	   # return 'Circle with coordinates {x}, {y}, and radius {radius} '.format(self.x, self.y, self.radius )    
        
x=4
y=2        
radius = 3
Circle=Circle(x,y,radius)
print (f"Circle with coordinates point at x= {x},y={y},Perimeter of a circle is {Circle.perimeter()},when the radius={radius}")
print (f"Circle with coordinates point at x= {x},y={y},Area of a circle is {Circle.area()},when the radius={radius}")

deltaX=3
deltaY=5
Circle.move(deltaX,deltaY)
print(f"After move,new X:{Circle.x}")
print(f"After move,New Y:{Circle.y}")
# print(Circle.y)


class Rectangle(Geometry):
     def __init__(self,x,y,length,width):
           self.x=x
           self.y=y
           self.length=length
           self.width=width
           
     def area(self):
         "Caculate the area of the rectangle"
         return self.length*self.width

     def perimeter(self):
         "Caculate the perimeter of the rectangle"
         return (self.length+self.width)*2  

     def move(self,deltaX,deltaY):
        self.x +=deltaX
        self.y +=deltaY

     def is_inside(self,x,y):
        self.x=x
        self.y=y
        #return        

x=5
y=8
length=10
width=6   
  
Rectangle=Rectangle(x,y,length,width)     
#print(Rectangle.x)

print (f"Rectangle with length={length},width={width} at the coordinates x={x},y={y},Perimeter of a Rectangle is {Rectangle.perimeter()}")
print (f"Rectangle with length={length},width={width} at the coordinates  x={x},y={y},Area of a Rectangle is {Rectangle.area()}")
deltaX=3
deltaY=5
Rectangle.move(deltaX,deltaY)
print(f"After move,New X:{Rectangle.x}")
print(f"After move,New Y:{Rectangle.y}")


class Square(Geometry):
     def __init__(self,x,y,side):
           self.x=x
           self.y=y
           self.side=side

           
     def area(self):
         "Caculate the area of the Square"
         return (self.side*self.side)

     def perimeter(self):
         "Caculate the perimeter of the Square"
         return (4*self.side )

     def move(self,deltaX,deltaY):
        self.x +=deltaX
        self.y +=deltaY   

     def is_inside(self,x,y):
        self.x=x
        self.y=y
        #return        

x=-5
y=-8
side=9
 
  
Square=Square(x,y,side)     
#print(Square.x)

print (f"Square with side={side}, at the coordinates x={x},y={y},Perimeter of a Square {Square.perimeter()}")
print (f"Square with side={side}, at the coordinates x={x},y={y},Area of a Square {Square.area()}")
deltaX=3
deltaY=5
Square.move(deltaX,deltaY)
print(f"After move,New X:{Square.x}")
print(f"After move,New Y:{Square.y}")
# Out:
# Circle with coordinates point at x= 4,y=2,Perimeter of a circle is 18.849,when the radius=3
# Circle with coordinates point at x= 4,y=2,Area of a circle is 28.273500000000002,when the radius=3
# After move,new X:7
# After move,New Y:7
# Rectangle with length=10,width=6 at the coordinates x=5,y=8,Perimeter of a Rectangle is 32
# Rectangle with length=10,width=6 at the coordinates  x=5,y=8,Area of a Rectangle is 60
# After move,New X:8
# After move,New Y:13
# Square with side=9, at the coordinates x=-5,y=-8,Perimeter of a Square 36
# Square with side=9, at the coordinates x=-5,y=-8,Area of a Square 81
# After move,New X:-2
# After move,New Y:-3

# %%
class Spheres():
    def __init__(self, x,y ,radius):
        self.x=x
        self.y=y
        self.radius = radius
        #self.area = 0
        #self.volume = 0


    def getRadius(self):
        return self.radius

    def surfaceArea(self):
        """Caculate the surface area of the spheres"""
        
        self.area = 4 * 3.14 * (radius*radius)
        return (self.area)

    def Volume(self):
        """Caculate the Volume area of the spheres"""
        self.volume = (4/3) * 3.14 * (radius *radius*radius)
        return (self.volume)
        
x=10
y=2        
radius = 3
Spheres=Spheres(x,y,radius)
print(Spheres.surfaceArea())
print(Spheres.Volume())

print (f"The surface area of Spheres with radius={radius} is {Spheres.surfaceArea()}")
print (f" The volume of Spheres with radius={radius} is {Spheres.Volume()}")
#print (f"Circle with coordinates point at x= {x},y={y},Area of a circle is {Circle.area()},when the radius={radius}")
# Out:
# 113.04
# 113.03999999999999
# The surface area of Spheres with radius=3 is 113.04
#  The volume of Spheres with radius=3 is 113.03999999999999

# %%
# circle class
   
class Circle():#child class
    def __init__(self,x,y ,radius):
        self.x=x
        self.y=y
        self.__radius=radius
    
    @property
    def radius(self):
        return self.__radius # read the hidden instance variable__radius

    @radius.setter    
    def radius(self,radius):
         if isinstance(radius,int) or isinstance(radius,float):
            self._radius=radius
         else :
             print("Wring type,please enter the correct type of radius") 

    @radius.setter
    def radius(self,radius):
         if radius<0:
             raise ValueError ("Radius should be a non-negative value")   
             #self._radius=radius 
MyCircle=Circle(x,y,radius)    
print(MyCircle.radius)  


    def area(self):
        "Caculate the area of the circle"
        return 3.1415* self.radius**2  #pi=3.1415 
    

    def perimeter(self):
        "Caculate the perimeter of the circle"
        return 2*3.1415*self.radius 

    def move(self,deltaX,deltaY):
        self.x +=deltaX
        self.y +=deltaY   

    def is_inside(self,givenX,givenY,x,y,radius): # at given point
        self.givenX=givenX
        self.givenY=givenY
        self.x=x
        self.y=y
        self.radius=radius
        
        if((givenX-x)*2+ (givenY-y)*2<=radius*2):
            return True;
        else:
             return False;   

    def__repr__(self):
       """self description for this circle instance,use by print(),str() and repr()"""  
       

    #def __str__(self): 
	   # return 'Circle with coordinates {x}, {y}, and radius {radius} '.format(self.x, self.y, self.radius )    
        
x=4
y=2        
radius = 3
Circle=Circle(x,y,radius)
print (f"Circle with coordinates point at x= {x},y={y},Perimeter of a circle is {Circle.perimeter()},when the radius={radius}")
print (f"Circle with coordinates point at x= {x},y={y},Area of a circle is {Circle.area()},when the radius={radius}")

deltaX=3
deltaY=5
Circle.move(deltaX,deltaY)
print(f"After move,new X:{Circle.x}")
print(f"After move,New Y:{Circle.y}")
# print(Circle.y)

givenX=8
givenY=6

is_inside=Circle.is_inside(givenX,givenY,x,y,radius)
print(f"New point at ({givenX},{givenY}),is {is_inside} of the inside of the circle with coordinates at x= {x},y={y},radius={radius}")
# Out:
#   File "C:\Users\Xiu\AppData\Local\Temp/ipykernel_18608/815914125.py", line 27
#     @property
#     ^
# IndentationError: unexpected indent

# %%
# circle class
   
class Circle():#child class
    def __init__(self,x,y ,radius):
        self.x=x
        self.y=y
        self.__radius=radius
    
    @property
    def radius(self):
        return self.__radius

    @radius.setter    
    def radius(self,radius):
         if isinstance(radius,int) or isinstance(radius,float):
            self._radius=radius
         else :
             print("Wring type,please enter the correct type of radius")  
MyCircle=Circle(x,y,radius)    
print(MyCircle.radius)  

#test wrong type except int and float
#MyCircle.radius="10"
#print(MyCircle.radius)

#test 
#属性名与@property 定义的属性名必须一样,如果不一样,在调用的时候就会报错 
#output :AttributeError:can't set attribute
""" 
    @property
    def radius(self):
        return self.__radius

    @radius.setter    
    def radius2(self,radius): #属性名与@property 定义的属性名必须一样,如果不一样,在调用的时候就会报错 
         if isinstance(radius,int) or isinstance(radius,float):
            self._radius=radius
         else :
             print("Please enter the correct type of radius")  
             
             """
# Out:
# 3
# ' \n    @property\n    def radius(self):\n        return self.__radius\n\n    @radius.setter    \n    def radius2(self,radius):\n         if isinstance(radius,int) or isinstance(radius,float):\n            self._radius=radius\n         else :\n             print("Please enter the correct type of radius")  \n             \n             '

# %%
# 正方型的点
class Rectangle():
     def __init__(self,x,y,length,width):
           self.x=x
           self.y=y
           self.length=length
           self.width=width
           
     def area(self):
         "Caculate the area of the rectangle"
         return self.length*self.width

     def perimeter(self):
         "Caculate the perimeter of the rectangle"
         return (self.length+self.width)*2  

     def move(self,deltaX,deltaY):
        self.x +=deltaX
        self.y +=deltaY

     
     def is_inside(self,givenX,givenY,x,y): # at given point
        self.givenX=givenX
        self.givenY=givenY
        self.x=x
        self.y=y
        
        
        if(x/2-givenX<=x <=x/2+givenX) and (y/2-givenY<=y <=y/2+givenY):
        
            return True;
        else:
             return False;    
#middle point(x,y)
x=5
y=8
length=10
width=6   

givenX=28
givenY=8
  
Rectangle=Rectangle(x,y,length,width)     
#print(Rectangle.x)

print (f"Rectangle with length={length},width={width} at the coordinates x={x},y={y},Perimeter of a Rectangle is {Rectangle.perimeter()}")
print (f"Rectangle with length={length},width={width} at the coordinates  x={x},y={y},Area of a Rectangle is {Rectangle.area()}")
deltaX=3
deltaY=5
Rectangle.move(deltaX,deltaY)
print(f"After move,New X:{Rectangle.x}")
print(f"After move,New Y:{Rectangle.y}")

is_inside=Rectangle.is_inside(x,y,givenX,givenY)
print(f"New point at ({givenX},{givenY}),is {is_inside} of the inside of the rectangle with middle point at x= {x},y={y}")
# Out:
# Rectangle with length=10,width=6 at the coordinates x=5,y=8,Perimeter of a Rectangle is 32
# Rectangle with length=10,width=6 at the coordinates  x=5,y=8,Area of a Rectangle is 60
# After move,New X:8
# After move,New Y:13
# New point at (28,8),is False of the inside of the rectangle with middle point at x= 5,y=8

# %%
# 球体
class Spheres():
    def __init__(self, x,y ,radius):
        self.x=x
        self.y=y
        self.radius = radius
        #self.area = 0
        #self.volume = 0


    def getRadius(self):
        return self.radius

    def surfaceArea(self):
        """Caculate the surface area of the spheres"""
        
        self.area = 4 * 3.14 * (radius*radius)
        return (self.area)

    def Volume(self):
        """Caculate the Volume area of the spheres"""
        self.volume = (4/3) * 3.14 * (radius *radius*radius)
        return (self.volume)
        
x=10
y=2        
radius = 3
Spheres=Spheres(x,y,radius)
print(Spheres.surfaceArea())
print(Spheres.Volume())

print (f"The surface area of Spheres with radius={radius} is {Spheres.surfaceArea()}")
print (f" The volume of Spheres with radius={radius} is {Spheres.Volume()}")
#print (f"Circle with coordinates point at x= {x},y={y},Area of a circle is {Circle.area()},when the radius={radius}")
# Out:
# 113.04
# 113.03999999999999
# The surface area of Spheres with radius=3 is 113.04
#  The volume of Spheres with radius=3 is 113.03999999999999

# %%
# 立方体
class Cube:
    def __init__(seflf, x,y,edge):
        self.edge = edge
        
    def surfaceArea(self):
        """Caculate the surface area of the cube"""
        
        self.area = 6* edge *edge
        return (self.area)
    
    
    def Volume(self):
        
        self.volume = edge*edge*edge
        return (self.volume)
    
    def main():
    Cuboid = Cuboid(3, 4, 5)
    l, w, h = cb.getDimensions()
    print("The length of the cuboid is", l)
    print("The width of the cuboid is", w)
    print("The height of the cuboid is", h)
    print("lateral surface area=", Cuboid.LateralSurfaceArea())
    print("surface area=", Cuboid.SurfaceArea())
    print("volume=", Cuboid.Volume())

main()
# Out:
#   File "C:\Users\Xiu\AppData\Local\Temp/ipykernel_18608/1684278628.py", line 19
#     Cuboid = Cuboid(3, 4, 5)
#     ^
# IndentationError: expected an indented block

# %%
class Geometry(): #parent class
    det__init__(self,x,y):
          self.x=x
    @property
    def x(self):
        return self.__x 
    @x.setter
    def x(self,radius):
        if radius>0:
            self.__x=True
        elif x,y=is_number
        else:
            self.x=radius


    def area(self):
        pass
    def perimeter(self):
        pass
    def volum(self):
        pass

# %% [markdown]
# # python之中特性（attribute）与属性（property）有什么区别？

# %%
# https://www.cnblogs.com/sincere-ye/p/13388834.html
class Circle(object):
    def __init__(self, radius,diameter):
        self.radius = radius
        self.diameter = diameter

# 实例化
my_circle = Circle(2,4)
print('radius is {}'.format(my_circle.radius))
print('diameter is {}'.format(my_circle.diameter))       

# 将直径改为6
my_circle.radius = 6 #change attribute
print('radius is {}'.format(my_circle.radius))
print('diameter is {}'.format(my_circle.diameter))

#我们发现，半径（radius）为2的时候，直径（diameter)为4。但是我们把半径改为6的时候，按照常理直径应该为8，但此时直径仍为4。
# 因此我们希望程序能够自动根据我们的半径值计算出对一个的直径，也能根据直径计算出对应的一个半径，这时候我们就需要@property了。
# Out:
# radius is 2
# diameter is 4
# radius is 6
# diameter is 4

# %%
# python之中特性（attribute）与属性（property）有什么区别？
class Circle(object):
    def __init__(self, radius):
        self.radius = radius
        
    @property
    def diameter(self):
        return self.radius * 2 # 定义直径等于半径*2
    @diameter.setter
    def diameter(self, new_diameter):
        self.radius = new_diameter / 2 #半径等于新的直径/2

# 实例化对象
my_circle = Circle(2) #半径=2
print('radius is {}'.format(my_circle.radius))
print('diameter is {}'.format(my_circle.diameter))

# 将半径改为6
my_circle.radius = 6
print('radius is {}'.format(my_circle.radius))
print('diameter is {}'.format(my_circle.diameter))

# 将直径改为6 
#my_circle.diameter = 6
#print('radius is {}'.format(my_circle.radius))
#print('diameter is {}'.format(my_circle.diameter))

#所以说属性（property）是一种特殊的特性（attribute）,其实property是一个有点函数意思的attribute
#我们现在一般常把attribute称作属性，那么对应的我们把property理解为属性函数，
#property其实就是一个带有函数功能的attribute，attribute的值是静态的，而property是一个动态的attribute，我们可以根据需要改变它的值。

# 而在本质上，property能够实现这个动态的改变值的功能，是由于它有__get__、__set__ 和 __delete__方法。
# 我们上面给diameter增加了@property和@diameter.setter，就是给diameter这个特性（attribute）增加了__get__ 和 __set__方法，
# 从而通过调用这两个方法去改变了原来静态的特性（attribute）值，使它成为了一个属性（property）。
# Out:
# radius is 2
# diameter is 4
# radius is 6
# diameter is 12

# %%
https://www.jianshu.com/p/c04931f91ac2

# %%
class MyCircle2(object):
    def __init__(self):
        self.__radius = 0

    @property
    def radius(self):
        return self.__radius

    @radius.setter 
    def radius(self, radius):
        if isinstance(radius, int) or isinstance(radius, float):
            self.__radius = radius
        else:
            print("请输入半径的正确类型")

mc3 = MyCircle2()
# 正确的半径
mc3.radius = 10
print(mc3.radius)

# 错误的半径值
mc3.radius = "1"
print(mc3.radius)

"""总结
@property 装饰的只读属性

在要转化为属性的方法前使用
将方法转化为属性使用逻辑
参数只能有一个self
如果只定义@property则属性将只读的
如果只定义@property的意义是将该属性定义成可以与其他属性联动效果的属性.
@setter 装饰的写检验属性

要用@属性名.setter
方法名必须与@property定义的属性名一样
参数除了self, 还必须有且只有一个参数,可以是不定长参数
定义@setter 的主要意义在于对属性赋值时,可以进行一个额外的处理

作者：爱编程的章老师
链接：https://www.jianshu.com/p/c04931f91ac2
来源：简书
著作权归作者所有。商业转载请联系作者获得授权，非商业转载请注明出处。"""

def tester():
c = Circle(10)
print c.radius

if __name__ == "__main__":
tester()

# %%
# https://books.google.se/books?id=mtU-EAAAQBAJ&pg=PA115&lpg=PA115&dq=python+class+circle+@property+radius+%3E0&source=bl&ots=0WyqZpnZ4V&sig=ACfU3U0pZOE1wbrJcq597OD4OWNKGA9cIg&hl=en&sa=X&ved=2ahUKEwjNkLvHm8PzAhWCrosKHUxTCH8Q6AF6BAgkEAM#v=onepage&q&f=false
